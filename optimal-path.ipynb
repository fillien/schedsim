# %%
import os
import shutil
import polars as pl
import glob

# %%
files = glob.glob('mcts-*.csv')
print(files)

dfs = []

for file in files:
    df = pl.read_csv(file, separator=';', has_header=False)
    df = df.rename({'column_1': 'taskset', 'column_2': 'status', 'column_3': 'mcts'})
    dfs.append(df)

combined = pl.concat(dfs).sort('taskset')

combined.write_csv('combined_mcts.csv')
# Out:
# ['mcts-laptop.csv', 'mcts-result.csv', 'mcts-desktop.csv']

# %%
combined
# Out:
# shape: (243, 3)
# ┌──────────────────────────┬─────────┬──────┐
# │ taskset                  ┆ status  ┆ mcts │
# │ ---                      ┆ ---     ┆ ---  │
# │ str                      ┆ str     ┆ i64  │
# ╞══════════════════════════╪═════════╪══════╡
# │ alloc_tasksets/1/1.json  ┆ optimal ┆ 0    │
# │ alloc_tasksets/1/1.json  ┆ optimal ┆ 0    │
# │ alloc_tasksets/1/10.json ┆ optimal ┆ 0    │
# │ alloc_tasksets/1/2.json  ┆ optimal ┆ 0    │
# │ alloc_tasksets/1/2.json  ┆ optimal ┆ 0    │
# │ …                        ┆ …       ┆ …    │
# │ alloc_tasksets/9/5.json  ┆ optimal ┆ 0    │
# │ alloc_tasksets/9/6.json  ┆ optimal ┆ 0    │
# │ alloc_tasksets/9/7.json  ┆ optimal ┆ 0    │
# │ alloc_tasksets/9/8.json  ┆ optimal ┆ 0    │
# │ alloc_tasksets/9/9.json  ┆ optimal ┆ 0    │
# └──────────────────────────┴─────────┴──────┘

# %%
set(range(1, 66, 2)) - set(sorted(set([int(i.split("/")[1]) for i in combined["taskset"]])))
# Out:
# {21, 23, 25, 27, 29, 31, 33, 57, 59}
